jpg
#   inflating: /content/extracted_data/__MACOSX/img_small/._de4373dc886db5aa8bbf9e56daf20714b24a22fa_9.jpg
#   inflating: /content/extracted_data/img_small/7d71bca3c900faa783039cb514f4bf320100ae03_2.jpg
#   inflating: /content/extracted_data/__MACOSX/img_small/._7d71bca3c900faa783039cb514f4bf320100ae03_2.jpg
#   inflating: /content/extracted_data/img_small/3054bd340a22b942b165304c3b272f8beee02938_1.jpg
#   inflating: /content/extracted_data/__MACOSX/img_small/._3054bd340a22b942b165304c3b272f8beee02938_1.jpg

# %%
import pandas as pd
import os
import torch
from PIL import Image
from torchvision import transforms
from transformers import BartTokenizer, BartForConditionalGeneration, VisualBertModel
from torchvision.models import resnet50
data = pd.read_csv('train_small.csv')

data['article'] = data['article'].apply(lambda x: x.strip().lower())

# %% [markdown]
# ### **文字特徵提取**

# %%
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
bart_model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')
bart_model.eval()

def extract_text_features(text):
    inputs = tokenizer(text, return_tensors="pt", max_length=512, truncation=True, padding="max_length")
    with torch.no_grad():
        outputs = bart_model(**inputs)
    return outputs.encoder_last_hidden_state.squeeze(0).mean(dim=0).numpy()

data['text_features'] = data['article'].apply(extract_text_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %% [markdown]
# ### **圖像特徵提取**

# %%
# 多圖片特徵提取
import os
import torch
from torchvision import models, transforms
from PIL import Image
from tqdm import tqdm

resnet = models.resnet50(pretrained=True)
resnet.eval()

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def extract_features(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)
    with torch.no_grad():
        features = resnet(image)
    return features.squeeze(0)

def process_images(file_name):
    images_dir = f'extracted_data/img_small/{file_name}_'
    features_list = []
    i = 1
    while os.path.exists(f'{images_dir}{i}.jpg'):
        features = extract_features(f'{images_dir}{i}.jpg')
        features_list.append(features)
        i += 1
    return torch.stack(features_list).mean(0)

data['image_features'] = data['fileName'].apply(process_images)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 100MB/s]

# %% [markdown]
# ### **VisualBERT文字與圖像特徵結合**

# %%
import torch.nn as nn
from transformers import VisualBertModel
visual_bert = VisualBertModel.from_pretrained('uclanlp/visualbert-vqa-coco-pre')

feature_size = 768
text_feature_transform = nn.Linear(1024, feature_size)
image_feature_transform = nn.Linear(1000, feature_size)


def combine_features_and_process(row):

    text_features = torch.tensor(row['text_features']).unsqueeze(0)
    image_features = torch.tensor(row['image_features']).unsqueeze(0)

    text_features = text_feature_transform(text_features)
    image_features = image_feature_transform(image_features)

    text_features = text_features.unsqueeze(1)
    image_features = image_features.unsqueeze(1)

    combined_features = torch.cat((text_features, image_features), dim=1)  # [1, 2, 768]

    inputs = {'inputs_embeds': combined_features}

    with torch.no_grad():
        outputs = visual_bert(**inputs)
        processed_features = outputs.last_hidden_state.mean(dim=1)

    return processed_features.squeeze().tolist()

data['combined_features'] = data.apply(combine_features_and_process, axis=1)
# Out:
# config.json:   0%|          | 0.00/631 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/448M [00:00<?, ?B/s]
# <ipython-input-5-e1d98d037688>:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   image_features = torch.tensor(row['image_features']).unsqueeze(0)

# %% [markdown]
# ### **生成摘要**

# %%
from transformers import BartForConditionalGeneration, BartTokenizer

tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
bart_model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn')

def generate_summary(combined_features, input_text, tokenizer, model):
    input_ids = tokenizer(input_text, return_tensors="pt", max_length=512, truncation=True, padding="max_length").input_ids

    with torch.no_grad():
        outputs = model.generate(input_ids=input_ids, max_length=150, num_beams=5, early_stopping=True)

    summary = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return summary

def process_and_generate_summary(row):
    summary = generate_summary(row['combined_features'], row['article'], tokenizer, bart_model)
    return summary


data['summary'] = data.apply(process_and_generate_summary, axis=1)

# %%
data
# Out:
#     id                                  fileName  \
# 0    1  3a248cb770b4d6fe080f7f95a5d595895d2be08d
# 1    2  ddebde43f3ea7f7b337458d2343bfa9c588f9314
# 2    3  39bde3d0752da393151a88b5fd6e3e31420da5d3
# 3    4  efa330032f8ec3542641cde4987b4586387d8d8c
# 4    5  244f37a23707ae549d2b593179444aaeb9c95578
# 5    6  0936f771136a2c42b1964bdec9dea77ed08a3ec3
# 6    7  ccc07dc8f51660232297409a6857eb98c02f00fc
# 7    8  b59e86169bfc81b8d87abcde78f680118cfd3e6e
# 8    9  ccf503f94bff06e5b3028321ead8c227ec1230b2
# 9   10  194cdfcb73a1d9c5b4a17763c4df87d8cdbe1c45
# 10  11  610be70c415920a696ca5a331c1955b35f273660
# 11  12  8e2e552fd230944fcec66009724776e330ee9e45
# 12  13  78e923ce9c40ac7d0e854f06b31b2d3e15ea159f
# 13  14  895a8ed8689142243799ab220eccbb01df8ab42f
# 14  15  053887bba0e4659de7b6260e5406fc8ca33be8f6
# 15  16  b2ad4524de6489c71b4d507671fdbb39b71b4687
# 16  17  cff5a03cea5e23931fd95be2cedb61324d5f3c33
# 17  18  3ebe744c3c49b00908d28dc7db2ab1ef2fe6e592
# 18  19  5eba6b4cf68231624c16ab7f5f169203d4b16587
# 19  20  ed97d8ae13bee07131c240f6c5bcf86ffb67e951
# 20  21  4dda9eacc1cf419963b446c60244444bf4e15bc6
# 21  22  f124a16f9094f35c197aedacede3426a0475e2a4
# 22  23  65016d94b9f492e703e244c44109c7fe88c85ec3
# 23  24  c3a35feb378f0e6cfc6c6ad7f4e4c1fd261f07c8
# 24  25  4ea09b7f220f627a9a1d191b3102d9ac8f592ff2
# 25  26  222ed954d570cf700c14da6d56a539acd5110149
# 26  27  57c9a3d27d29ddb02648d0cc7232b16f9a761a14
# 27  28  99cc78ba4a9754072f4a45bf791b1e35e10bdf32
# 28  29  58871958102cff92a923e8b1113e8b68d9a6bba6
# 29  30  80bf026e767dd226c6d443d39b135d0cb59deffe
# 30  31  b8f5c90da12171ebf23967b85143b685ea7adbbc
# 31  32  f873fd86c849b59819e2357f1a9395818d206b52
# 32  33  4ca7f99294e090c370dcd8b96de5ed394c4a4f87
# 33  34  a18526d3759875143ff48fea1c2d2f900c453e80
# 34  35  e957301c03a770076a7414ab0bb488a00743fff6
# 35  36  3054bd340a22b942b165304c3b272f8beee02938
# 36  37  01f3d382064ea8fed7603ee74361d632e3b13120
# 37  38  de4373dc886db5aa8bbf9e56daf20714b24a22fa
# 38  39  5549b980603a581766489e2a3f34bde15500cbfc
# 39  40  e98db57d65cc4f4381589f83dddaaea052e4fcd3
# 40  41  5a2025561b28e2771e6c7be6d43b2ad5f83f1b9c
# 41  42  13c53b15312702cf52a7290206940daaa7a4c6fa
# 42  43  b9db332cb3e02d79cc4bb568b002758216db6816
# 43  44  3c03e02f856c4f7cb3380d6516a4aeb6a0a964ad
# 44  45  6987738948a2e4abca9510fd2b593dc2f0cd4852
# 45  46  7d71bca3c900faa783039cb514f4bf320100ae03
# 46  47  32b49457afcbe5cb28a79225ca766c1866a9c42e
# 47  48  5b340948636bf0a2558d54c32b2fee8ce473f542
# 48  49  ad1a608ed768d841304c8f7c9e2638a204b61b8c
# 49  50  f45f75a96eabef71300963c567c0d83686122531
#
#                                               article  \
# 0   if you listen to twitter , kendall and kylie j...
# 1   a new jersey family is reeling tuesday after a...
# 2   the bank of england is set to launch a crackdo...
# 3   russian president vladimir putin is fond of ol...
# 4   it is 26 years since europe 's most prestigiou...
# 5   tamara taylor is chomping at the bit to appear...
# 6   they could become one of the premier league 's...
# 7   two cousins charged with the brutal deaths of ...
# 8   former democratic national committee chair rep...
# 9   a disgusted easyjet passenger has complained a...
# 10  bernard tomic has been dumped by his racket sp...
# 11  ander herrera is desperate for his team-mate a...
# 12  diehard conservative remainers yesterday threa...
# 13  for millions of myspace users , it has likely ...
# 14  the wife of late linkin park frontman chester ...
# 15  one of donald trump 's private helicopters was...
# 16  a man who murdered his millionaire author fian...
# 17  pioneering new ` eco-friendly underpants ' pro...
# 18  a community in indiana has rallied around a 17...
# 19  offices and classrooms across the country are ...
# 20  it was another disappointing downward slide fo...
# 21  here is everything you need to know about the ...
# 22  jesus ibarra , a 19-year-old engineering stude...
# 23  believing things will work out for the best ma...
# 24  a dog is a girl 's best friend !\na video post...
# 25  barcelona terror attack suspect younes abouyaa...
# 26  federal police searched the house of carlos nu...
# 27  a college administrator has been charged follo...
# 28  a portrait of author and blogger constance hal...
# 29  an ex-police officer who worked as part of a c...
# 30  raucous irish fans have taken over las vegas a...
# 31  a buddhist monk has been convicted of the atte...
# 32  thousands of short-snouted pooches descended o...
# 33  antonio conte was facing a full-blown crisis o...
# 34  mass evacuations are underway today after hurr...
# 35  it 's one of the nation 's favourite biscuits ...
# 36  a fitness blogger has sparked a heated debate ...
# 37  they may be a tad late , but the lauren family...
# 38  the european union has been accused of paying ...
# 39  a playboy model who starred alongside michael ...
# 40  luke shaw is looking to make his mark on the m...
# 41  police in connecticut have arrested a hedge fu...
# 42  the ferocious tyrannosaurus rex was too big to...
# 43  an unemployed father arrested over the hacking...
# 44  self-styled godman gurmeet ram rahim singh , w...
# 45  a texas officer funded his failed political ca...
# 46  boxer amir khan and his estranged wife faryal ...
# 47  in perhaps the most american form of haute cou...
# 48  robots are now so smart they can work out whet...
# 49  twenty years after her death , those who loved...
#
#                                               summary  \
# 0   Kendall + kylie clothing brand released an ima...
# 1   A new jersey family is reeling t Tuesday after...
# 2   Bank of england set to launch a crackdown this...
# 3   Russian president vladimir putin is fond of ol...
# 4   It is 26 years since europe's most prestigious...
# 5   tamara taylor is chomping at the bit to appear...
# 6   The re-signing of zlatan ibrahimovic on a one-...
# 7   cosmo dinardo, a 20-year-old drug dealer with ...
# 8   Former democratic national committee chair rep...
# 9   A disgusted easyjet passenger has complained a...
# 10  bernard tomic has been dumped by his racket sp...
# 11  ander herrera is desperate for his team-mate a...
# 12  Remain-supporting mps geared up for an autumn ...
# 13  Security expert found that old profiles are ea...
# 14  talinda bennington posted the 40 second video ...
# 15  one of donald trump's private helicopters was ...
# 16  Stewart drugged helen bailey with sleeping pil...
# 17  Finnish designers claim their new range of box...
# 18  audrey lupton was diagnosed with rhabdomyosarc...
# 19  half of the 88,357 cases of flu in australia t...
# 20  This is the fifth straight episode that has po...
# 21  Only 11 under 20 english players featured in t...
# 22  Jesus ibarra, 19, has been barely able to walk...
# 23  believing things will work out for the best ma...
# 24  A video posted online shows the adorable momen...
# 25  barcelona terror attack suspect younes abouyaa...
# 26  federal police searched the house of carlos nu...
# 27  Cyclist tyler noe and friend greg goodman were...
# 28  a portrait of author and blogger constance hal...
# 29  An ex-police officer who worked as part of a c...
# 30  raucous irish fans have taken over las vegas a...
# 31  a buddhist monk has been convicted of the atte...
# 32  Pugfest was set up by martin clowes as a tribu...
# 33  antonio conte is facing a full-blown crisis af...
# 34  Mass evacuations are underway today after hurr...
# 35  Biscuit lovers took to social media to complai...
# 36  Fitness blogger louise aubery has sparked a he...
# 37   lauren bush lauren, 33, and her family celebr...
# 38  The european union has been accused of paying ...
# 39  ola ray, 57, played the king of pop's girlfrie...
# 40  luke shaw is looking to make his mark on the m...
# 41  Police in connecticut have arrested a hedge fu...
# 42  Scientists have worked out the dinosaur's maxi...
# 43  website designer nathan wyatt, 35, was quizzed...
# 44  self-styled godman gurmeet ram rahim singh was...
# 45  geovani hernandez ran for sheriff in hidalgo c...
# 46  boxer amir khan and his estranged wife faryal ...
# 47  The national rifle association put on a concea...
# 48  robots are now so smart they can work out whet...
# 49  Twenty years after her death, those who loved ...
#
#                                         text_features  \
# 0   [0.021653915, -0.11024898, -0.0676152, -0.0596...
# 1   [0.10130456, -0.23067634, -0.03522276, -0.0583...
# 2   [0.0022704469, -0.12262584, -0.36360878, -0.06...
# 3   [0.13126874, -0.1570257, -0.09135373, -0.02925...
# 4   [0.10788613, -0.16137244, -0.06229935, -0.0389...
# 5   [0.04333487, -0.11163817, -0.270213, -0.076347...
# 6   [0.1055755, -0.12388456, -0.039798126, -0.0552...
# 7   [0.10521533, -0.13344398, -0.0568666, -0.02211...
# 8   [0.061565414, -0.068867505, -0.1003509, -0.038...
# 9   [0.033479735, -0.11282287, -0.19271486, -0.038...
# 10  [0.012723178, -0.13174409, -0.37863585, -0.066...
# 11  [0.065382615, -0.10444864, -0.28220567, -0.090...
# 12  [0.0754316, -0.06447861, -0.10233103, -0.04343...
# 13  [0.08150573, -0.16499427, -0.0038019568, -0.06...
# 14  [0.084193565, -0.11212876, -0.038490873, -0.06...
# 15  [0.04627263, -0.051619317, -0.3025374, -0.0465...
# 16  [0.07684533, -0.13383003, -0.12330974, -0.0439...
# 17  [0.08016202, -0.18163246, -0.070468426, -0.056...
# 18  [0.11805922, -0.1664707, -0.036248554, -0.0516...
# 19  [0.07481545, -0.20047167, -0.0034325104, -0.00...
# 20  [0.07556212, -0.032754645, -0.11965604, -0.058...
# 21  [0.08216937, -0.15113214, -0.08477631, -0.0396...
# 22  [0.09888998, -0.19511336, -0.032964498, -0.032...
# 23  [0.10436909, -0.21344319, -0.09241341, -0.0363...
# 24  [-0.018863164, -0.05015216, -0.39014977, -0.08...
# 25  [0.10297178, -0.102159195, -0.03784726, -0.027...
# 26  [0.12737131, -0.12297436, -0.065415636, -0.031...
# 27  [0.108753085, -0.110285185, -0.037369102, -0.0...
# 28  [0.06753909, -0.16042568, -0.12830941, -0.0623...
# 29  [0.09379443, -0.12489321, -0.06545169, -0.0243...
# 30  [0.07222957, -0.08226016, -0.07056566, -0.0457...
# 31  [0.080116555, -0.06865616, -0.16591163, -0.044...
# 32  [0.027546346, -0.08454041, -0.28440157, -0.051...
# 33  [0.062643364, -0.14428818, -0.16814794, -0.047...
# 34  [0.05569098, -0.051491395, -0.031046987, -0.00...
# 35  [0.048738766, -0.15457079, -0.14475943, -0.050...
# 36  [0.09117703, -0.17381349, -0.016170967, -0.040...
# 37  [0.09959908, -0.21503232, -0.037483215, -0.054...
# 38  [0.10784182, -0.018561028, -0.071618184, -0.01...
# 39  [0.11150563, -0.0705846, -0.025104543, -0.0482...
# 40  [0.11454961, -0.19824716, -0.05936712, -0.0594...
# 41  [0.065710455, -0.12473053, -0.062289473, -0.01...
# 42  [0.06006004, -0.14252329, -0.021692501, -0.044...
# 43  [0.088352814, -0.1379115, -0.07653053, -0.0369...
# 44  [0.09400499, -0.10605185, -0.04523851, -0.0160...
# 45  [0.09918022, -0.1049657, -0.053263612, -0.0287...
# 46  [0.117448315, -0.13225938, -0.05385883, -0.049...
# 47  [0.08849317, -0.08529352, -0.06139185, -0.0280...
# 48  [0.08171199, -0.18335988, -0.025798157, -0.043...
# 49  [0.11925926, -0.20900242, -0.035086397, -0.046...
#
#                                        image_features  \
# 0   [tensor(-0.9112), tensor(-1.3345), tensor(-0.7...
# 1   [tensor(0.5088), tensor(-0.8531), tensor(0.120...
# 2   [tensor(-0.8591), tensor(-1.0623), tensor(-3.0...
# 3   [tensor(-0.7379), tensor(-1.1619), tensor(0.41...
# 4   [tensor(-0.2991), tensor(-1.1571), tensor(0.52...
# 5   [tensor(-1.7187), tensor(-1.6331), tensor(-1.4...
# 6   [tensor(-0.9841), tensor(-1.0619), tensor(0.09...
# 7   [tensor(1.5255), tensor(0.2995), tensor(-0.374...
# 8   [tensor(-0.7756), tensor(-0.9958), tensor(0.28...
# 9   [tensor(-0.0837), tensor(-0.2329), tensor(-0.4...
# 10  [tensor(1.3092), tensor(-0.4993), tensor(-0.05...
# 11  [tensor(-1.4452), tensor(-1.3601), tensor(-1.3...
# 12  [tensor(0.1163), tensor(-1.0539), tensor(-1.62...
# 13  [tensor(-1.4493), tensor(-0.9820), tensor(-2.0...
# 14  [tensor(1.8803), tensor(-2.1350), tensor(-1.05...
# 15  [tensor(-2.9150), tensor(-1.6844), tensor(0.53...
# 16  [tensor(1.6378), tensor(-0.5030), tensor(-0.47...
# 17  [tensor(0.7189), tensor(-1.0105), tensor(0.454...
# 18  [tensor(-0.0262), tensor(-0.9711), tensor(0.20...
# 19  [tensor(-1.5180), tensor(-0.3455), tensor(-1.9...
# 20  [tensor(-0.9149), tensor(-2.6041), tensor(-3.5...
# 21  [tensor(-3.4647), tensor(-2.1180), tensor(-0.6...
# 22  [tensor(-1.5936), tensor(-1.8297), tensor(-1.1...
# 23  [tensor(-2.5224), tensor(-0.2322), tensor(-4.2...
# 24  [tensor(-1.0651), tensor(-0.5309), tensor(-1.9...
# 25  [tensor(0.5223), tensor(-0.8970), tensor(-0.32...
# 26  [tensor(-1.6750), tensor(-1.6260), tensor(1.15...
# 27  [tensor(3.8878), tensor(-0.7008), tensor(0.306...
# 28  [tensor(-0.8887), tensor(0.4835), tensor(-0.91...
# 29  [tensor(2.7503), tensor(-0.6901), tensor(-0.36...
# 30  [tensor(-1.6001), tensor(-0.7255), tensor(0.78...
# 31  [tensor(0.4312), tensor(-0.6018), tensor(-0.65...
# 32  [tensor(0.0857), tensor(-0.2054), tensor(-1.58...
# 33  [tensor(-3.0638), tensor(-1.3482), tensor(1.58...
# 34  [tensor(-1.2292), tensor(-0.8241), tensor(0.29...
# 35  [tensor(-0.3299), tensor(-0.3129), tensor(-0.9...
# 36  [tensor(-0.7837), tensor(-1.9360), tensor(0.02...
# 37  [tensor(0.4886), tensor(-0.7432), tensor(-0.11...
# 38  [tensor(-1.7690), tensor(-0.2394), tensor(-0.0...
# 39  [tensor(0.0245), tensor(0.5169), tensor(-0.234...
# 40  [tensor(-0.7818), tensor(-0.8663), tensor(-0.5...
# 41  [tensor(2.2405), tensor(-0.5597), tensor(-1.58...
# 42  [tensor(-2.0146), tensor(-0.1162), tensor(-0.3...
# 43  [tensor(-0.3093), tensor(-2.1964), tensor(-1.3...
# 44  [tensor(-2.5380), tensor(-0.2650), tensor(-1.0...
# 45  [tensor(4.6350), tensor(-0.5642), tensor(0.321...
# 46  [tensor(-1.0923), tensor(-0.8663), tensor(-0.6...
# 47  [tensor(-0.2888), tensor(-0.9814), tensor(0.02...
# 48  [tensor(-2.2261), tensor(-2.1852), tensor(-0.6...
# 49  [tensor(-0.3704), tensor(-1.0478), tensor(0.31...
#
#                                     combined_features
# 0   [-0.5087100863456726, 0.6678800582885742, 0.13...
# 1   [-0.6280848979949951, 0.6786677837371826, -0.1...
# 2   [0.5949293375015259, 0.2056165337562561, -0.07...
# 3   [-0.6749867796897888, 0.4144148826599121, 0.05...
# 4   [-0.469675213098526, 0.6555590629577637, -0.10...
# 5   [-0.1837862879037857, 0.4726242423057556, -0.4...
# 6   [-0.22483065724372864, 0.7355657815933228, 0.1...
# 7   [-1.061955451965332, 0.44963696599006653, -0.0...
# 8   [-0.5605597496032715, 0.6661292910575867, 0.11...
# 9   [-0.6560893058776855, 0.6043345928192139, 0.04...
# 10  [0.6298446655273438, 0.08330649137496948, 0.18...
# 11  [0.4230254292488098, 0.40936097502708435, -0.1...
# 12  [-0.5844342708587646, 0.5480962991714478, -0.0...
# 13  [-0.30328768491744995, 0.7244429588317871, 0.1...
# 14  [-0.5136617422103882, 0.11983045190572739, -0....
# 15  [0.5330872535705566, -0.04452423006296158, -0....
# 16  [-0.32860615849494934, 0.6245296001434326, -0....
# 17  [-0.6076886653900146, 0.48578107357025146, -0....
# 18  [-0.13493293523788452, 0.5712248086929321, 0.1...
# 19  [-0.8385733962059021, 0.4579124450683594, -0.2...
# 20  [-0.4214923679828644, 0.9201962947845459, 0.35...
# 21  [-0.5043966174125671, 0.5887032747268677, 0.17...
# 22  [-0.5000613927841187, 0.6544503569602966, -0.1...
# 23  [-0.12777094542980194, 0.6284781098365784, 0.1...
# 24  [-0.03576849773526192, 0.2848689556121826, -0....
# 25  [-0.030113916844129562, 0.700453519821167, 0.1...
# 26  [-0.1832534670829773, 0.54376620054245, -0.019...
# 27  [-0.2772209048271179, 0.8765276670455933, 0.37...
# 28  [-1.1412181854248047, 0.2691737413406372, -0.3...
# 29  [-0.16047507524490356, 0.927529513835907, -0.1...
# 30  [-0.5836477279663086, 0.6489046812057495, -0.1...
# 31  [-0.13955698907375336, 0.3477720022201538, 0.3...
# 32  [0.5307338833808899, 0.46062108874320984, -0.3...
# 33  [-0.3618413209915161, 0.6455520391464233, -0.1...
# 34  [-0.5870736837387085, 0.13128449022769928, 0.1...
# 35  [-0.6436938643455505, 0.7602030634880066, -0.1...
# 36  [-0.9226313829421997, 0.5086990594863892, -0.0...
# 37  [-0.7778435945510864, 0.5643900632858276, -0.2...
# 38  [-0.36794888973236084, 0.8556194305419922, 0.0...
# 39  [-0.3794805407524109, 0.5665714740753174, -0.0...
# 40  [-0.23251420259475708, 0.670050859451294, -0.0...
# 41  [-0.5443955659866333, 0.9466512203216553, -0.1...
# 42  [-1.0120561122894287, 0.03924711048603058, -0....
# 43  [-0.37117427587509155, 0.5383492708206177, 0.2...
# 44  [0.1883973479270935, 0.4578552842140198, 0.203...
# 45  [-0.6033953428268433, 0.7740128040313721, -0.2...
# 46  [-1.091555118560791, 0.1833476722240448, -0.34...
# 47  [-0.42366984486579895, 0.7368338108062744, -0....
# 48  [-0.47759300470352173, 0.5492362976074219, -0....
# 49  [-0.057437971234321594, 0.5656629204750061, 0....

# %% [markdown]
# ### **評估指標**

# %%
from rouge import Rouge


rouge = Rouge()


rouge_1_scores = []
rouge_2_scores = []
rouge_l_scores = []


for index, row in data.iterrows():
    scores = rouge.get_scores(row['summary'], row['article'])
    rouge_1_scores.append(scores[0]['rouge-1']['f'])
    rouge_2_scores.append(scores[0]['rouge-2']['f'])
    rouge_l_scores.append(scores[0]['rouge-l']['f'])

avg_rouge_1 = sum(rouge_1_scores) / len(rouge_1_scores)
avg_rouge_2 = sum(rouge_2_scores) / len(rouge_2_scores)
avg_rouge_l = sum(rouge_l_scores) / len(rouge_l_scores)

print(f"Average ROUGE-1 Score: {avg_rouge_1}")
print(f"Average ROUGE-2 Score: {avg_rouge_2}")
print(f"Average ROUGE-L Score: {avg_rouge_l}")

# %% [markdown]
# ### **加載預訓練模型**

# %%
import os
import torch
from torchvision import models, transforms
from PIL import Image
import pandas as pd
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

resnet = models.resnet50(pretrained=True)
resnet.eval()


tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
bert_model = AutoModel.from_pretrained('bert-base-uncased')
bert_model.eval()


transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %% [markdown]
# ### **特徵提取函數**

# %%
from sklearn.decomposition import PCA

def extract_image_features(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)
    with torch.no_grad():
        features = resnet(image)
    return features.cpu().numpy().flatten()[:768]


def extract_text_features(text):
    inputs = tokenizer(text, return_tensors="pt")
    with torch.no_grad():
        outputs = bert_model(**inputs)
    return outputs.last_hidden_state[:, 0, :].detach().cpu().numpy()

# %% [markdown]
# ### **找出與summary最符合的圖片**

# %%
def find_most_relevant_image(file_name, summary):
    base_path = f'extracted_data/img_small/{file_name}_'
    text_features = extract_text_features(summary).flatten()
    best_image = None
    best_similarity = -1

    i = 1
    while os.path.exists(f'{base_path}{i}.jpg'):
        img_path = f'{base_path}{i}.jpg'
        image_features = extract_image_features(img_path)
        similarity = cosine_similarity([text_features], [image_features])[0][0]

        if similarity > best_similarity:
            best_similarity = similarity
            best_image = img_path

        i += 1

    return best_image

# %%
data['most_relevant_image'] = data.apply(lambda x: find_most_relevant_image(x['fileName'], x['summary']), axis=1)

# %%
data
# Out:
#     id                                  fileName  \
# 0    1  3a248cb770b4d6fe080f7f95a5d595895d2be08d
# 1    2  ddebde43f3ea7f7b337458d2343bfa9c588f9314
# 2    3  39bde3d0752da393151a88b5fd6e3e31420da5d3
# 3    4  efa330032f8ec3542641cde4987b4586387d8d8c
# 4    5  244f37a23707ae549d2b593179444aaeb9c95578
# 5    6  0936f771136a2c42b1964bdec9dea77ed08a3ec3
# 6    7  ccc07dc8f51660232297409a6857eb98c02f00fc
# 7    8  b59e86169bfc81b8d87abcde78f680118cfd3e6e
# 8    9  ccf503f94bff06e5b3028321ead8c227ec1230b2
# 9   10  194cdfcb73a1d9c5b4a17763c4df87d8cdbe1c45
# 10  11  610be70c415920a696ca5a331c1955b35f273660
# 11  12  8e2e552fd230944fcec66009724776e330ee9e45
# 12  13  78e923ce9c40ac7d0e854f06b31b2d3e15ea159f
# 13  14  895a8ed8689142243799ab220eccbb01df8ab42f
# 14  15  053887bba0e4659de7b6260e5406fc8ca33be8f6
# 15  16  b2ad4524de6489c71b4d507671fdbb39b71b4687
# 16  17  cff5a03cea5e23931fd95be2cedb61324d5f3c33
# 17  18  3ebe744c3c49b00908d28dc7db2ab1ef2fe6e592
# 18  19  5eba6b4cf68231624c16ab7f5f169203d4b16587
# 19  20  ed97d8ae13bee07131c240f6c5bcf86ffb67e951
# 20  21  4dda9eacc1cf419963b446c60244444bf4e15bc6
# 21  22  f124a16f9094f35c197aedacede3426a0475e2a4
# 22  23  65016d94b9f492e703e244c44109c7fe88c85ec3
# 23  24  c3a35feb378f0e6cfc6c6ad7f4e4c1fd261f07c8
# 24  25  4ea09b7f220f627a9a1d191b3102d9ac8f592ff2
# 25  26  222ed954d570cf700c14da6d56a539acd5110149
# 26  27  57c9a3d27d29ddb02648d0cc7232b16f9a761a14
# 27  28  99cc78ba4a9754072f4a45bf791b1e35e10bdf32
# 28  29  58871958102cff92a923e8b1113e8b68d9a6bba6
# 29  30  80bf026e767dd226c6d443d39b135d0cb59deffe
# 30  31  b8f5c90da12171ebf23967b85143b685ea7adbbc
# 31  32  f873fd86c849b59819e2357f1a9395818d206b52
# 32  33  4ca7f99294e090c370dcd8b96de5ed394c4a4f87
# 33  34  a18526d3759875143ff48fea1c2d2f900c453e80
# 34  35  e957301c03a770076a7414ab0bb488a00743fff6
# 35  36  3054bd340a22b942b165304c3b272f8beee02938
# 36  37  01f3d382064ea8fed7603ee74361d632e3b13120
# 37  38  de4373dc886db5aa8bbf9e56daf20714b24a22fa
# 38  39  5549b980603a581766489e2a3f34bde15500cbfc
# 39  40  e98db57d65cc4f4381589f83dddaaea052e4fcd3
# 40  41  5a2025561b28e2771e6c7be6d43b2ad5f83f1b9c
# 41  42  13c53b15312702cf52a7290206940daaa7a4c6fa
# 42  43  b9db332cb3e02d79cc4bb568b002758216db6816
# 43  44  3c03e02f856c4f7cb3380d6516a4aeb6a0a964ad
# 44  45  6987738948a2e4abca9510fd2b593dc2f0cd4852
# 45  46  7d71bca3c900faa783039cb514f4bf320100ae03
# 46  47  32b49457afcbe5cb28a79225ca766c1866a9c42e
# 47  48  5b340948636bf0a2558d54c32b2fee8ce473f542
# 48  49  ad1a608ed768d841304c8f7c9e2638a204b61b8c
# 49  50  f45f75a96eabef71300963c567c0d83686122531
#
#                                               article  \
# 0   if you listen to twitter , kendall and kylie j...
# 1   a new jersey family is reeling tuesday after a...
# 2   the bank of england is set to launch a crackdo...
# 3   russian president vladimir putin is fond of ol...
# 4   it is 26 years since europe 's most prestigiou...
# 5   tamara taylor is chomping at the bit to appear...
# 6   they could become one of the premier league 's...
# 7   two cousins charged with the brutal deaths of ...
# 8   former democratic national committee chair rep...
# 9   a disgusted easyjet passenger has complained a...
# 10  bernard tomic has been dumped by his racket sp...
# 11  ander herrera is desperate for his team-mate a...
# 12  diehard conservative remainers yesterday threa...
# 13  for millions of myspace users , it has likely ...
# 14  the wife of late linkin park frontman chester ...
# 15  one of donald trump 's private helicopters was...
# 16  a man who murdered his millionaire author fian...
# 17  pioneering new ` eco-friendly underpants ' pro...
# 18  a community in indiana has rallied around a 17...
# 19  offices and classrooms across the country are ...
# 20  it was another disappointing downward slide fo...
# 21  here is everything you need to know about the ...
# 22  jesus ibarra , a 19-year-old engineering stude...
# 23  believing things will work out for the best ma...
# 24  a dog is a girl 's best friend !\na video post...
# 25  barcelona terror attack suspect younes abouyaa...
# 26  federal police searched the house of carlos nu...
# 27  a college administrator has been charged follo...
# 28  a portrait of author and blogger constance hal...
# 29  an ex-police officer who worked as part of a c...
# 30  raucous irish fans have taken over las vegas a...
# 31  a buddhist monk has been convicted of the atte...
# 32  thousands of short-snouted pooches descended o...
# 33  antonio conte was facing a full-blown crisis o...
# 2   [0.0022704469, -0.12262584, -0.36360878, -0.06...
# 3   [0.13126874, -0.1570257, -0.09135373, -0.02925...
# 4   [0.10788613, -0.16137244, -0.06229935, -0.0389...
# 5   [0.04333487, -0.11163817, -0.270213, -0.076347...
# 6   [0.1055755, -0.12388456, -0.039798126, -0.0552...
# 7   [0.10521533, -0.13344398, -0.0568666, -0.02211...
# 8   [0.061565414, -0.068867505, -0.1003509, -0.038...
# 9   [0.033479735, -0.11282287, -0.19271486, -0.038...
# 10  [0.012723178, -0.13174409, -0.37863585, -0.066...
# 11  [0.065382615, -0.10444864, -0.28220567, -0.090...
# 12  [0.0754316, -0.06447861, -0.10233103, -0.04343...
# 13  [0.08150573, -0.16499427, -0.0038019568, -0.06...
# 14  [0.084193565, -0.11212876, -0.038490873, -0.06...
# 15  [0.04627263, -0.051619317, -0.3025374, -0.0465...
# 16  [0.07684533, -0.13383003, -0.12330974, -0.0439...
# 17  [0.08016202, -0.18163246, -0.070468426, -0.056...
# 18  [0.11805922, -0.1664707, -0.036248554, -0.0516...
# 19  [0.07481545, -0.20047167, -0.0034325104, -0.00...
# 20  [0.07556212, -0.032754645, -0.11965604, -0.058...
# 21  [0.08216937, -0.15113214, -0.08477631, -0.0396...
# 22  [0.09888998, -0.19511336, -0.032964498, -0.032...
# 23  [0.10436909, -0.21344319, -0.09241341, -0.0363...
# 24  [-0.018863164, -0.05015216, -0.39014977, -0.08...
# 25  [0.10297178, -0.102159195, -0.03784726, -0.027...
# 26  [0.12737131, -0.12297436, -0.065415636, -0.031...
# 27  [0.108753085, -0.110285185, -0.037369102, -0.0...
# 28  [0.06753909, -0.16042568, -0.12830941, -0.0623...
# 29  [0.09379443, -0.12489321, -0.06545169, -0.0243...
# 30  [0.07222957, -0.08226016, -0.07056566, -0.0457...
# 31  [0.080116555, -0.06865616, -0.16591163, -0.044...
# 32  [0.027546346, -0.08454041, -0.28440157, -0.051...
# 33  [0.062643364, -0.14428818, -0.16814794, -0.047...
# 34  [0.05569098, -0.051491395, -0.031046987, -0.00...
# 35  [0.048738766, -0.15457079, -0.14475943, -0.050...
# 36  [0.09117703, -0.17381349, -0.016170967, -0.040...
# 37  [0.09959908, -0.21503232, -0.037483215, -0.054...
# 38  [0.10784182, -0.018561028, -0.071618184, -0.01...
# 39  [0.11150563, -0.0705846, -0.025104543, -0.0482...
# 40  [0.11454961, -0.19824716, -0.05936712, -0.0594...
# 41  [0.065710455, -0.12473053, -0.062289473, -0.01...
# 42  [0.06006004, -0.14252329, -0.021692501, -0.044...
# 43  [0.088352814, -0.1379115, -0.07653053, -0.0369...
# 44  [0.09400499, -0.10605185, -0.04523851, -0.0160...
# 45  [0.09918022, -0.1049657, -0.053263612, -0.0287...
# 46  [0.117448315, -0.13225938, -0.05385883, -0.049...
# 47  [0.08849317, -0.08529352, -0.06139185, -0.0280...
# 48  [0.08171199, -0.18335988, -0.025798157, -0.043...
# 49  [0.11925926, -0.20900242, -0.035086397, -0.046...
#
#                                        image_features  \
# 0   [tensor(-0.9112), tensor(-1.3345), tensor(-0.7...
# 1   [tensor(0.5088), tensor(-0.8531), tensor(0.120...
# 2   [tensor(-0.8591), tensor(-1.0623), tensor(-3.0...
# 3   [tensor(-0.7379), tensor(-1.1619), tensor(0.41...
# 4   [tensor(-0.2991), tensor(-1.1571), tensor(0.52...
# 5   [tensor(-1.7187), tensor(-1.6331), tensor(-1.4...
# 6   [tensor(-0.9841), tensor(-1.0619), tensor(0.09...
# 7   [tensor(1.5255), tensor(0.2995), tensor(-0.374...
# 8   [tensor(-0.7756), tensor(-0.9958), tensor(0.28...
# 9   [tensor(-0.0837), tensor(-0.2329), tensor(-0.4...
# 10  [tensor(1.3092), tensor(-0.4993), tensor(-0.05...
# 11  [tensor(-1.4452), tensor(-1.3601), tensor(-1.3...
# 12  [tensor(0.1163), tensor(-1.0539), tensor(-1.62...
# 13  [tensor(-1.4493), tensor(-0.9820), tensor(-2.0...
# 14  [tensor(1.8803), tensor(-2.1350), tensor(-1.05...
# 15  [tensor(-2.9150), tensor(-1.6844), tensor(0.53...
# 16  [tensor(1.6378), tensor(-0.5030), tensor(-0.47...
# 17  [tensor(0.7189), tensor(-1.0105), tensor(0.454...
# 18  [tensor(-0.0262), tensor(-0.9711), tensor(0.20...
# 19  [tensor(-1.5180), tensor(-0.3455), tensor(-1.9...
# 20  [tensor(-0.9149), tensor(-2.6041), tensor(-3.5...
# 21  [tensor(-3.4647), tensor(-2.1180), tensor(-0.6...
# 22  [tensor(-1.5936), tensor(-1.8297), tensor(-1.1...
# 23  [tensor(-2.5224), tensor(-0.2322), tensor(-4.2...
# 24  [tensor(-1.0651), tensor(-0.5309), tensor(-1.9...
# 25  [tensor(0.5223), tensor(-0.8970), tensor(-0.32...
# 26  [tensor(-1.6750), tensor(-1.6260), tensor(1.15...
# 27  [tensor(3.8878), tensor(-0.7008), tensor(0.306...
# 28  [tensor(-0.8887), tensor(0.4835), tensor(-0.91...
# 29  [tensor(2.7503), tensor(-0.6901), tensor(-0.36...
# 30  [tensor(-1.6001), tensor(-0.7255), tensor(0.78...
# 31  [tensor(0.4312), tensor(-0.6018), tensor(-0.65...
# 32  [tensor(0.0857), tensor(-0.2054), tensor(-1.58...
# 33  [tensor(-3.0638), tensor(-1.3482), tensor(1.58...
# 34  [tensor(-1.2292), tensor(-0.8241), tensor(0.29...
# 35  [tensor(-0.3299), tensor(-0.3129), tensor(-0.9...
# 36  [tensor(-0.7837), tensor(-1.9360), tensor(0.02...
# 37  [tensor(0.4886), tensor(-0.7432), tensor(-0.11...
# 38  [tensor(-1.7690), tensor(-0.2394), tensor(-0.0...
# 39  [tensor(0.0245), tensor(0.5169), tensor(-0.234...
# 40  [tensor(-0.7818), tensor(-0.8663), tensor(-0.5...
# 41  [tensor(2.2405), tensor(-0.5597), tensor(-1.58...
# 42  [tensor(-2.0146), tensor(-0.1162), tensor(-0.3...
# 43  [tensor(-0.3093), tensor(-2.1964), tensor(-1.3...
# 44  [tensor(-2.5380), tensor(-0.2650), tensor(-1.0...
# 45  [tensor(4.6350), tensor(-0.5642), tensor(0.321...
# 46  [tensor(-1.0923), tensor(-0.8663), tensor(-0.6...
# 47  [tensor(-0.2888), tensor(-0.9814), tensor(0.02...
# 48  [tensor(-2.2261), tensor(-2.1852), tensor(-0.6...
# 49  [tensor(-0.3704), tensor(-1.0478), tensor(0.31...
#
#                                     combined_features  \
# 0   [-0.5087100863456726, 0.6678800582885742, 0.13...
# 1   [-0.6280848979949951, 0.6786677837371826, -0.1...
# 2   [0.5949293375015259, 0.2056165337562561, -0.07...
# 3   [-0.6749867796897888, 0.4144148826599121, 0.05...
# 4   [-0.469675213098526, 0.6555590629577637, -0.10...
# 5   [-0.1837862879037857, 0.4726242423057556, -0.4...
# 6   [-0.22483065724372864, 0.7355657815933228, 0.1...
# 7   [-1.061955451965332, 0.44963696599006653, -0.0...
# 8   [-0.5605597496032715, 0.6661292910575867, 0.11...
# 9   [-0.6560893058776855, 0.6043345928192139, 0.04...
# 10  [0.6298446655273438, 0.08330649137496948, 0.18...
# 11  [0.4230254292488098, 0.40936097502708435, -0.1...
# 12  [-0.5844342708587646, 0.5480962991714478, -0.0...
# 13  [-0.30328768491744995, 0.7244429588317871, 0.1...
# 14  [-0.5136617422103882, 0.11983045190572739, -0....
# 15  [0.5330872535705566, -0.04452423006296158, -0....
# 16  [-0.32860615849494934, 0.6245296001434326, -0....
# 17  [-0.6076886653900146, 0.48578107357025146, -0....
# 18  [-0.13493293523788452, 0.5712248086929321, 0.1...
# 19  [-0.8385733962059021, 0.4579124450683594, -0.2...
# 20  [-0.4214923679828644, 0.9201962947845459, 0.35...
# 21  [-0.5043966174125671, 0.5887032747268677, 0.17...
# 22  [-0.5000613927841187, 0.6544503569602966, -0.1...
# 23  [-0.12777094542980194, 0.6284781098365784, 0.1...
# 24  [-0.03576849773526192, 0.2848689556121826, -0....
# 25  [-0.030113916844129562, 0.700453519821167, 0.1...
# 26  [-0.1832534670829773, 0.54376620054245, -0.019...
# 27  [-0.2772209048271179, 0.8765276670455933, 0.37...
# 28  [-1.1412181854248047, 0.2691737413406372, -0.3...
# 29  [-0.16047507524490356, 0.927529513835907, -0.1...
# 30  [-0.5836477279663086, 0.6489046812057495, -0.1...
# 31  [-0.13955698907375336, 0.3477720022201538, 0.3...
# 32  [0.5307338833808899, 0.46062108874320984, -0.3...
# 33  [-0.3618413209915161, 0.6455520391464233, -0.1...
# 34  [-0.5870736837387085, 0.13128449022769928, 0.1...
# 35  [-0.6436938643455505, 0.7602030634880066, -0.1...
# 36  [-0.9226313829421997, 0.5086990594863892, -0.0...
# 37  [-0.7778435945510864, 0.5643900632858276, -0.2...
# 38  [-0.36794888973236084, 0.8556194305419922, 0.0...
# 39  [-0.3794805407524109, 0.5665714740753174, -0.0...
# 40  [-0.23251420259475708, 0.670050859451294, -0.0...
# 41  [-0.5443955659866333, 0.9466512203216553, -0.1...
# 42  [-1.0120561122894287, 0.03924711048603058, -0....
# 43  [-0.37117427587509155, 0.5383492708206177, 0.2...
# 46  extracted_data/img_small/32b49457afcbe5cb28a79...
# 47  extracted_data/img_small/5b340948636bf0a2558d5...
# 48  extracted_data/img_small/ad1a608ed768d841304c8...
# 49  extracted_data/img_small/f45f75a96eabef7130096...

# %% [markdown]
# ### **用餘弦定理計算summary與圖像的相關性**

# %%
# 餘弦定理
import os
import torch
from torchvision import models, transforms
from PIL import Image
import pandas as pd
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity


resnet = models.resnet50(pretrained=True)
resnet.eval()


tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
bert_model = AutoModel.from_pretrained('bert-base-uncased')
bert_model.eval()

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def extract_image_features(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)
    with torch.no_grad():
        features = resnet(image)
    return features.cpu().numpy().flatten()[:768]

def extract_text_features(text):
    inputs = tokenizer(text, return_tensors="pt")
    with torch.no_grad():
        outputs = bert_model(**inputs)
    return outputs.last_hidden_state[:, 0, :].detach().cpu().numpy()

def find_most_relevant_image(file_name, summary):
    base_path = f'extracted_data/img_small/{file_name}_'
    text_features = extract_text_features(summary).flatten()
    best_image = None
    best_similarity = -1

    i = 1
    while os.path.exists(f'{base_path}{i}.jpg'):
        img_path = f'{base_path}{i}.jpg'
        image_features = extract_image_features(img_path)
        similarity = cosine_similarity([text_features], [image_features])[0][0]

        if similarity > best_similarity:
            best_similarity = similarity
            best_image = img_path

        i += 1

    return best_image, best_similarity


data['result'] = data.apply(lambda x: find_most_relevant_image(x['fileName'], x['summary']), axis=1)
data['most_relevant_image'] = data['result'].apply(lambda x: x[0])
data['image_text_relevance'] = data['result'].apply(lambda x: x[1])
data.drop('result', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
average_relevance_score = data['image_text_relevance'].mean()

print("餘弦定理平均圖文相關度分數為:", average_relevance_score)

# %% [markdown]
# ### **用歐式距離計算summary與圖像的相關性**

# %%
# 歐式距離
import os
import torch
from torchvision import models, transforms
from PIL import Image
import pandas as pd
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import euclidean_distances


resnet = models.resnet50(pretrained=True)
resnet.eval()

tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
bert_model = AutoModel.from_pretrained('bert-base-uncased')
bert_model.eval()

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def extract_image_features(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)
    with torch.no_grad():
        features = resnet(image)
    return features.cpu().numpy().flatten()[:768]

def extract_text_features(text):
    inputs = tokenizer(text, return_tensors="pt")
    with torch.no_grad():
        outputs = bert_model(**inputs)
    return outputs.last_hidden_state[:, 0, :].detach().cpu().numpy()

def find_most_relevant_image(file_name, summary):
    base_path = f'extracted_data/img_small/{file_name}_'
    text_features = extract_text_features(summary).flatten()
    best_image = None
    best_distance = float('inf')

    i = 1
    while os.path.exists(f'{base_path}{i}.jpg'):
        img_path = f'{base_path}{i}.jpg'
        image_features = extract_image_features(img_path)
        distance = euclidean_distances([text_features], [image_features])[0][0]

        if distance < best_distance:
            best_distance = distance
            best_image = img_path

        i += 1

    return best_image, best_distance


data['result'] = data.apply(lambda x: find_most_relevant_image(x['fileName'], x['summary']), axis=1)
data['most_relevant_image'] = data['result'].apply(lambda x: x[0])
data['image_text_relevance'] = data['result'].apply(lambda x: x[1])
data.drop('result', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
average_relevance_score = data['image_text_relevance'].mean()

print("歐式距離平均圖文相關度分數為:", average_relevance_score)
